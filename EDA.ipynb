# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('./datas/cars.csv')
df
# Out:
#             Make      Model        Variant Ex-Showroom_Price Displacement  \
# 0           Tata  Nano Genx             Xt      Rs. 2,92,667       624 cc
# 1           Tata  Nano Genx             Xe      Rs. 2,36,447       624 cc
# 2           Tata  Nano Genx        Emax Xm      Rs. 2,96,661       624 cc
# 3           Tata  Nano Genx            Xta      Rs. 3,34,768       624 cc
# 4           Tata  Nano Genx             Xm      Rs. 2,72,223       624 cc
# ...          ...        ...            ...               ...          ...
# 1271       Honda       City   Vx Mt Diesel     Rs. 13,02,000      1498 cc
# 1272       Honda       City   Zx Mt Diesel     Rs. 14,21,000      1498 cc
# 1273       Honda       City  Zx Cvt Petrol     Rs. 14,31,000      1497 cc
# 1274       Honda       City   V Cvt Petrol     Rs. 12,01,000      1497 cc
# 1275  Mitsubishi    Montero         3.2 At     Rs. 68,62,560      3200 cc
#
#       Cylinders  Valves_Per_Cylinder               Drivetrain  \
# ...

# %%
df.shape
# Out:
# (1276, 140)

# %%
df.describe().T
# Out:
#                       count      mean       std  min  25%  50%  75%   max
# Cylinders            1210.0  4.380992  1.660957  2.0  4.0  4.0  4.0  16.0
# Valves_Per_Cylinder  1174.0  3.977853  0.833763  1.0  4.0  4.0  4.0  16.0
# Doors                1272.0  4.550314  0.747816  2.0  4.0  5.0  5.0   5.0
# Seating_Capacity     1270.0  5.270079  1.145231  2.0  5.0  5.0  5.0  16.0
# Number_of_Airbags    1141.0  3.787029  2.522399  1.0  2.0  2.0  6.0  14.0
# USB_Ports              29.0  1.793103  0.773642  1.0  1.0  2.0  2.0   3.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Columns: 140 entries, Make to Electric_Range
# dtypes: float64(6), object(134)
# memory usage: 1.4+ MB

# %%
df.isna().sum()
# Out:
# Make                   75
# Model                   0
# Variant                 0
# Ex-Showroom_Price       0
# Displacement           12
#                      ...
# USB_Ports            1247
# Heads-Up_Display     1225
# Welcome_Lights       1207
# Battery              1263
# Electric_Range       1259
# Length: 140, dtype: int64

# %%
cars = df.copy()
cars
# Out:
#             Make      Model        Variant Ex-Showroom_Price Displacement  \
# 0           Tata  Nano Genx             Xt      Rs. 2,92,667       624 cc
# 1           Tata  Nano Genx             Xe      Rs. 2,36,447       624 cc
# 2           Tata  Nano Genx        Emax Xm      Rs. 2,96,661       624 cc
# 3           Tata  Nano Genx            Xta      Rs. 3,34,768       624 cc
# 4           Tata  Nano Genx             Xm      Rs. 2,72,223       624 cc
# ...          ...        ...            ...               ...          ...
# 1271       Honda       City   Vx Mt Diesel     Rs. 13,02,000      1498 cc
# 1272       Honda       City   Zx Mt Diesel     Rs. 14,21,000      1498 cc
# 1273       Honda       City  Zx Cvt Petrol     Rs. 14,31,000      1497 cc
# 1274       Honda       City   V Cvt Petrol     Rs. 12,01,000      1497 cc
# 1275  Mitsubishi    Montero         3.2 At     Rs. 68,62,560      3200 cc
#
#       Cylinders  Valves_Per_Cylinder               Drivetrain  \
# ...

# %%
cars['Make'].value_counts()
# Out:
# Make
# Maruti Suzuki       149
# Hyundai             130
# Mahindra            119
# Tata                100
# Toyota               82
# Honda                64
# Ford                 43
# Skoda                43
# Bmw                  37
# Renault              36
# Volkswagen           34
# Audi                 31
# Nissan               29
# Jeep                 28
# Land Rover Rover     27
# Fiat                 23
# Jaguar               22
# Kia                  21
# Volvo                18
# Datsun               15
# Maruti Suzuki R      14
# Porsche              14
# Mg                   13
# Lamborghini          13
# Icml                 11
# Mini                 10
# Land Rover           10
# Lexus                10
# Maserati              9
# Ferrari               8
# Mitsubishi            7
# Premier               6
# Bentley               6
# Force                 6
# Isuzu                 5
# Aston Martin          3
# Bugatti               2
# Bajaj                 2
# ...

# %%
cars = cars[cars['Make'].notna()]
cars
# Out:
#             Make      Model        Variant Ex-Showroom_Price Displacement  \
# 0           Tata  Nano Genx             Xt      Rs. 2,92,667       624 cc
# 1           Tata  Nano Genx             Xe      Rs. 2,36,447       624 cc
# 2           Tata  Nano Genx        Emax Xm      Rs. 2,96,661       624 cc
# 3           Tata  Nano Genx            Xta      Rs. 3,34,768       624 cc
# 4           Tata  Nano Genx             Xm      Rs. 2,72,223       624 cc
# ...          ...        ...            ...               ...          ...
# 1271       Honda       City   Vx Mt Diesel     Rs. 13,02,000      1498 cc
# 1272       Honda       City   Zx Mt Diesel     Rs. 14,21,000      1498 cc
# 1273       Honda       City  Zx Cvt Petrol     Rs. 14,31,000      1497 cc
# 1274       Honda       City   V Cvt Petrol     Rs. 12,01,000      1497 cc
# 1275  Mitsubishi    Montero         3.2 At     Rs. 68,62,560      3200 cc
#
#       Cylinders  Valves_Per_Cylinder               Drivetrain  \
# ...

# %%
cars.isna().sum()
# Out:
# Make                    0
# Model                   0
# Variant                 0
# Ex-Showroom_Price       0
# Displacement           11
#                      ...
# USB_Ports            1172
# Heads-Up_Display     1155
# Welcome_Lights       1138
# Battery              1188
# Electric_Range       1184
# Length: 140, dtype: int64

# %%
n = len(cars.Displacement)
n
# Out:
# 1201

# %%
int(cars.Displacement[3].split(' ')[0])
# Out:
# 624

# %%
cars['Displacement'].unique()
# Out:
# array(['624 cc', '799 cc', '999 cc', '1196 cc', '998 cc', '1198 cc',
#        '1086 cc', '1199 cc', '1197 cc', '1173 cc', '1489 cc', '1248 cc',
#        '1364 cc', '1193 cc', '1396 cc', '1186 cc', '1498 cc', '1194 cc',
#        '1496 cc', '1461 cc', '1368 cc', '1956 cc', '2999 cc', '2157 cc',
#        '1968 cc', '1997 cc', '1597 cc', '1798 cc', '1395 cc', '2000 cc',
#        '1998 cc', '1969 cc', '1999 cc', '1984 cc', '1995 cc', '2995 cc',
#        '2993 cc', '2998 cc', '4951 cc', '2987 cc', '6417 cc', '3604 cc',
#        '2979 cc', '1988 cc', '2982 cc', '3456 cc', '2894 cc', '6592 cc',
#        '4691 cc', '3996 cc', '4461 cc', '5204 cc', '5998 cc', '3855 cc',
#        '5950 cc', '5198 cc', '4497 cc', '6752 cc', '7993 cc', '216 cc',
#        '796 cc', '1120 cc', '1497 cc', '1994 cc', '1298 cc', '1397 cc',
#        '1493 cc', '2523 cc', '1591 cc', '1582 cc', '1598 cc', nan,
#        '2498 cc', '2596 cc', '2149 cc', '1462 cc', '2179 cc', '72 cc',
# ...

# %%
mode_value = cars.Displacement.mode()
mode_value
# Out:
# 0    1197 cc
# Name: Displacement, dtype: object

# %%
cars.Displacement.fillna("1197 cc", inplace=True)
cars.Displacement.unique()
# Out:
# /tmp/ipykernel_21857/3314136295.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars.Displacement.fillna("1197 cc", inplace=True)
# /tmp/ipykernel_21857/3314136295.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars.Displacement.fillna("1197 cc", inplace=True)
# ...

# %%
cars.Displacement = cars.Displacement.str.replace(' cc','').astype(int)
cars.head(10)
# Out:
# /tmp/ipykernel_21857/1605139891.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars.Displacement = cars.Displacement.str.replace(' cc','').astype(int)
#      Make      Model  Variant Ex-Showroom_Price  Displacement  Cylinders  \
# 0    Tata  Nano Genx       Xt      Rs. 2,92,667           624        2.0
# 1    Tata  Nano Genx       Xe      Rs. 2,36,447           624        2.0
# 2    Tata  Nano Genx  Emax Xm      Rs. 2,96,661           624        2.0
# 3    Tata  Nano Genx      Xta      Rs. 3,34,768           624        2.0
# 4    Tata  Nano Genx       Xm      Rs. 2,72,223           624        2.0
# 5    Tata  Nano Genx      Xma      Rs. 3,14,815           624        2.0
# ...

# %%
cars['Ex-Showroom_Price'] = cars['Ex-Showroom_Price'].str.replace('Rs. ','')
cars['Ex-Showroom_Price'] = cars['Ex-Showroom_Price'].str.replace(',','').astype(int)
cars
# Out:
# /tmp/ipykernel_21857/2240741750.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars['Ex-Showroom_Price'] = cars['Ex-Showroom_Price'].str.replace('Rs. ','')
# /tmp/ipykernel_21857/2240741750.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars['Ex-Showroom_Price'] = cars['Ex-Showroom_Price'].str.replace(',','').astype(int)
#             Make      Model        Variant  Ex-Showroom_Price  Displacement  \
# 0           Tata  Nano Genx             Xt             292667           624
# ...

# %%
cars = cars[cars['Drivetrain'].notna()]
cars.head()
# Out:
#    Make      Model  Variant  Ex-Showroom_Price  Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt             292667           624        2.0
# 1  Tata  Nano Genx       Xe             236447           624        2.0
# 2  Tata  Nano Genx  Emax Xm             296661           624        2.0
# 3  Tata  Nano Genx      Xta             334768           624        2.0
# 4  Tata  Nano Genx       Xm             272223           624        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# ...

# %%
from sklearn import preprocessing 
le = preprocessing.LabelEncoder()

# %%
cars.Drivetrain = le.fit_transform(cars.Drivetrain)
cars.Drivetrain
# Out:
# /tmp/ipykernel_21857/3135190005.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars.Drivetrain = le.fit_transform(cars.Drivetrain)
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1271    2
# 1272    2
# 1273    2
# 1274    2
# 1275    1
# Name: Drivetrain, Length: 1195, dtype: int64

# %%
cars.head()
# Out:
#    Make      Model  Variant  Ex-Showroom_Price  Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt             292667           624        2.0
# 1  Tata  Nano Genx       Xe             236447           624        2.0
# 2  Tata  Nano Genx  Emax Xm             296661           624        2.0
# 3  Tata  Nano Genx      Xta             334768           624        2.0
# 4  Tata  Nano Genx       Xm             272223           624        2.0
#
#    Valves_Per_Cylinder  Drivetrain Cylinder_Configuration Emission_Norm  ...  \
# 0                  2.0           3                In-line         BS IV  ...
# 1                  2.0           3                In-line         BS IV  ...
# 2                  2.0           3                In-line         BS IV  ...
# 3                  2.0           3                In-line         BS IV  ...
# 4                  2.0           3                In-line         BS IV  ...
#
#   Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# ...

# %%
plt.hist(cars['Ex-Showroom_Price'], bins=20)
plt.show()

# %%
cars['Ex-Showroom_Price'].dtype
# Out:
# dtype('int64')

# %%
cars[cars['Make']=='Tata']['Model'].unique()
# Out:
# array(['Nano Genx', 'Tiago', 'Bolt', 'Altroz', 'Tigor', 'Zest', 'Nexon',
#        'Tigor Ev', 'Hexa', 'Safari Storme', 'Nexon Ev', 'Harrier',
#        'Tiago Nrg', 'Winger'], dtype=object)

# %%
cars.Emission_Norm.unique()
# Out:
# array(['BS IV', 'BS 6', nan, 'BS III', 'BS VI'], dtype=object)

# %%
cars = cars[cars['Cylinders'].notna()]
cars.head()
# Out:
#    Make      Model  Variant  Ex-Showroom_Price  Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt             292667           624        2.0
# 1  Tata  Nano Genx       Xe             236447           624        2.0
# 2  Tata  Nano Genx  Emax Xm             296661           624        2.0
# 3  Tata  Nano Genx      Xta             334768           624        2.0
# 4  Tata  Nano Genx       Xm             272223           624        2.0
#
#    Valves_Per_Cylinder  Drivetrain Cylinder_Configuration Emission_Norm  ...  \
# 0                  2.0           3                In-line         BS IV  ...
# 1                  2.0           3                In-line         BS IV  ...
# 2                  2.0           3                In-line         BS IV  ...
# 3                  2.0           3                In-line         BS IV  ...
# 4                  2.0           3                In-line         BS IV  ...
#
#   Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# ...

# %%
cars.Cylinders = cars.Cylinders.astype(int)
cars
# Out:
#             Make      Model        Variant  Ex-Showroom_Price  Displacement  \
# 0           Tata  Nano Genx             Xt             292667           624
# 1           Tata  Nano Genx             Xe             236447           624
# 2           Tata  Nano Genx        Emax Xm             296661           624
# 3           Tata  Nano Genx            Xta             334768           624
# 4           Tata  Nano Genx             Xm             272223           624
# ...          ...        ...            ...                ...           ...
# 1271       Honda       City   Vx Mt Diesel            1302000          1498
# 1272       Honda       City   Zx Mt Diesel            1421000          1498
# 1273       Honda       City  Zx Cvt Petrol            1431000          1497
# 1274       Honda       City   V Cvt Petrol            1201000          1497
# 1275  Mitsubishi    Montero         3.2 At            6862560          3200
#
# ...

# %%
cylinders = cars.Cylinders.unique()
cylinders
# Out:
# array([ 2,  3,  4,  5,  6,  8, 12, 10, 16])

# %%
for i in cylinders:
    plt.scatter(cars[cars.Cylinders == i]['Cylinders'], cars[cars.Cylinders == i]['Displacement'])

# %%
plt.scatter(cars['Cylinders'], cars['Displacement'])

# %%
sns.regplot(x ='Cylinders', y = 'Displacement', data = cars)
# Out:
# <Axes: xlabel='Cylinders', ylabel='Displacement'>

# %%
sns.pairplot(cars)

# %%
cars.Cylinder_Configuration.unique()
# Out:
# array(['In-line', 'V', 'Flat', 'W', nan], dtype=object)

# %%
sns.regplot(x ='Cylinders', y = 'Ex-Showroom_Price', data = cars)
# Out:
# <Axes: xlabel='Cylinders', ylabel='Ex-Showroom_Price'>
